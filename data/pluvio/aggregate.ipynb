# %%
import pandas as pd

# %%
# !ls
# Out:
# aggregate.ipynb                 manhuacu.csv
# aguas_vermelhas.csv             mantena.csv
# aimores.csv                     maria_da_fe.csv
# almenara.csv                    mocambinho.csv
# aracuai.csv                     montalvania.csv
# araxa.csv                       monte_verde.csv
# bambui.csv                      montes_claros.csv
# barbacena.csv                   muriae.csv
# belo_horizonte_(pampulha).csv   nova_porteirinha_(janauba).csv
# belo_horizonte_-_cercadinho.csv oliveira.csv
# buritis.csv                     ouro_branco.csv
# caldas.csv                      paracatu.csv
# campina_verde.csv               passa_quatro.csv
# capelinha.csv                   passos.csv
# caratinga.csv                   patos_de_minas.csv
# chapada_gaucha.csv              patrocinio.csv
# conceicao_das_alagoas.csv       pirapora.csv
# coronel_pacheco.csv             pompeu.csv
# curvelo.csv                     rio_pardo_de_minas.csv
# diamantina.csv                  sacramento.csv
# divinopolis.csv                 salinas.csv
# dores_do_indaia.csv             sao_joao_del_rei.csv
# espinosa.csv                    sao_romao.csv
# florestal.csv                   sao_sebastiao_do_paraiso.csv
# formiga.csv                     serra_dos_aimores.csv
# governador_valadares.csv        sete_lagoas.csv
# guanhaes.csv                    teofilo_otoni.csv
# guarda-mor.csv                  timoteo.csv
# ibirite_(rola_moca).csv         tres_marias.csv
# itaobim.csv                     uberaba.csv
# ituiutaba.csv                   uberlandia.csv
# januaria.csv                    unai.csv
# joao_pinheiro.csv               varginha.csv
# juiz_de_fora.csv                vicosa.csv
# machado.csv

# %%
# Liste der CSV-Dateien (Städtenamen)
csv_files = [
    "aguas_vermelhas.csv", "aimores.csv", "almenara.csv", "aracuai.csv", "araxa.csv", "bambui.csv", "barbacena.csv",
    "belo_horizonte_(pampulha).csv", "belo_horizonte_-_cercadinho.csv", "buritis.csv", "caldas.csv", "campina_verde.csv",
    "capelinha.csv", "caratinga.csv", "chapada_gaucha.csv", "conceicao_das_alagoas.csv", "coronel_pacheco.csv",
    "curvelo.csv", "diamantina.csv", "divinopolis.csv", "dores_do_indaia.csv", "espinosa.csv", "florestal.csv",
    "formiga.csv", "governador_valadares.csv", "guanhaes.csv", "guarda-mor.csv", "ibirite_(rola_moca).csv", "itaobim.csv",
    "ituiutaba.csv", "januaria.csv", "joao_pinheiro.csv", "juiz_de_fora.csv", "machado.csv", "manhuacu.csv", "mantena.csv",
    "maria_da_fe.csv", "mocambinho.csv", "montalvania.csv", "monte_verde.csv", "montes_claros.csv", "muriae.csv",
    "nova_porteirinha_(janauba).csv", "oliveira.csv", "ouro_branco.csv", "paracatu.csv", "passa_quatro.csv", "passos.csv",
    "patos_de_minas.csv", "patrocinio.csv", "pirapora.csv", "pompeu.csv", "rio_pardo_de_minas.csv", "sacramento.csv",
    "salinas.csv", "sao_joao_del_rei.csv", "sao_romao.csv", "sao_sebastiao_do_paraiso.csv", "serra_dos_aimores.csv",
    "sete_lagoas.csv", "teofilo_otoni.csv", "timoteo.csv", "tres_marias.csv", "uberaba.csv", "uberlandia.csv", "unai.csv",
    "varginha.csv", "vicosa.csv"
]

# Liste der Städte in der Form einer Mapping-Anforderung
city_groups = [
    "Alfenas,Machado", "Guaxupé", "Itajubá", "Lavras", "Poços de Caldas", "Pouso Alegre", "São Lourenço", 
    "São Sebastião do Paraíso", "Três Corações", "Três Pontas", "Varginha", "Barbacena", "São João Del Rei", 
    "Belo Horizonte,Nova Lima,Santa Luzia", "Betim", "Contagem", "Curvelo", "Guanhães", "Itabira", "Ouro Preto", 
    "João Monlevade", "Sete Lagoas", "Vespasiano,Lagoa Santa", "Diamantina,Itamarandiba", 
    "Turmalina,Minas Novas,Capelinha", "Bom Despacho", "Formiga", "Itaúna", "Pará de Minas,Nova Serrana", 
    "Caratinga", "Coronel Fabriciano,Timóteo", "Governador Valadares", "Ipatinga", "Mantena", "Resplendor", 
    "Além Paraíba", "Carangola", "Leopoldina,Cataguases", "Muriaé", "Santos Dumont", "São João Nepomuceno,Bicas", 
    "Ubá", "Coração de Jesus", "Francisco Sá", "Janaúba,Monte Azul", "Januária", "Pirapora", "Patos de Minas", 
    "Unaí,Paracatu", "Manhuaçu", "Ponte Nova", "Viçosa", "Araçuaí", "Itaobim", "Nanuque", "Padre Paraíso", 
    "Pedra azul", "Araxá", "Frutal,Iturama", "Uberaba", "Ituiutaba", "Patrocínio,Monte Carmelo", "Uberlândia,Araguari", 
    "Manga", "João Pinheiro", "Congonhas", "Conselheiro Lafaiete", "São Gotardo", "Bocaiúva", "Montes Claros", 
    "Taiobeiras", "Divinópolis", "Lagoa da Prata,Santo Antônio do Monte", "Oliveira,Santo Antônio do Amparo", 
    "Campo Belo", "Lima Duarte", "Cássia", "Passos", "Piumhi", "Almenara,Jacinto", "Serro", "Itambacuri", 
    "Juiz de Fora", "Salinas", "Teófilo Otoni,Malacacheta", "São Francisco", "Brasília de Minas", 
    "Peçanha,São João Evangelista,Santa Maria do Suaçuí"
]

# Dictionary erstellen
mapping = {}

for group in city_groups:
    matching_files = []
    for city in group.split(","):
        for csv_file in csv_files:
            # Überprüfen, ob der CSV-Dateiname die Stadt enthält
            if city.lower()\
                .replace(" ", "_")\
                .replace('ç','c')\
                .replace('á','a')\
                .replace('é','e')\
                .replace('í','i')\
                .replace('ó','o')\
                .replace('ú','u')\
            in csv_file:
                matching_files.append(csv_file)
    mapping[group] = matching_files

# Ergebnis anzeigen
mapping
# Out:
# {'Alfenas,Machado': ['machado.csv'],
#  'Guaxupé': [],
#  'Itajubá': [],
#  'Lavras': [],
#  'Poços de Caldas': [],
#  'Pouso Alegre': [],
#  'São Lourenço': [],
#  'São Sebastião do Paraíso': [],
#  'Três Corações': [],
#  'Três Pontas': [],
#  'Varginha': ['varginha.csv'],
#  'Barbacena': ['barbacena.csv'],
#  'São João Del Rei': [],
#  'Belo Horizonte,Nova Lima,Santa Luzia': ['belo_horizonte_(pampulha).csv',
#   'belo_horizonte_-_cercadinho.csv'],
#  'Betim': [],
#  'Contagem': [],
#  'Curvelo': ['curvelo.csv'],
#  'Guanhães': [],
#  'Itabira': [],
#  'Ouro Preto': [],
#  'João Monlevade': [],
#  'Sete Lagoas': ['sete_lagoas.csv'],
#  'Vespasiano,Lagoa Santa': [],
#  'Diamantina,Itamarandiba': ['diamantina.csv'],
#  'Turmalina,Minas Novas,Capelinha': ['capelinha.csv'],
#  'Bom Despacho': [],
#  'Formiga': ['formiga.csv'],
#  'Itaúna': [],
#  'Pará de Minas,Nova Serrana': [],
#  'Caratinga': ['caratinga.csv'],
#  'Coronel Fabriciano,Timóteo': ['timoteo.csv'],
#  'Governador Valadares': ['governador_valadares.csv'],
#  'Ipatinga': [],
#  'Mantena': ['mantena.csv'],
#  'Resplendor': [],
#  'Além Paraíba': [],
#  'Carangola': [],
#  'Leopoldina,Cataguases': [],
#  'Muriaé': ['muriae.csv'],
#  'Santos Dumont': [],
#  'São João Nepomuceno,Bicas': [],
#  'Ubá': ['nova_porteirinha_(janauba).csv'],
#  'Coração de Jesus': [],
#  'Francisco Sá': [],
#  'Janaúba,Monte Azul': ['nova_porteirinha_(janauba).csv'],
#  'Januária': ['januaria.csv'],
#  'Pirapora': ['pirapora.csv'],
#  'Patos de Minas': ['patos_de_minas.csv'],
#  'Unaí,Paracatu': ['unai.csv', 'paracatu.csv'],
#  'Manhuaçu': ['manhuacu.csv'],
#  'Ponte Nova': [],
#  'Viçosa': ['vicosa.csv'],
#  'Araçuaí': ['aracuai.csv'],
#  'Itaobim': ['itaobim.csv'],
#  'Nanuque': [],
#  'Padre Paraíso': [],
#  'Pedra azul': [],
#  'Araxá': ['araxa.csv'],
#  'Frutal,Iturama': [],
#  'Uberaba': ['uberaba.csv'],
#  'Ituiutaba': ['ituiutaba.csv'],
#  'Patrocínio,Monte Carmelo': ['patrocinio.csv'],
#  'Uberlândia,Araguari': [],
#  'Manga': [],
#  'João Pinheiro': [],
#  'Congonhas': [],
#  'Conselheiro Lafaiete': [],
#  'São Gotardo': [],
#  'Bocaiúva': [],
#  'Montes Claros': ['montes_claros.csv'],
#  'Taiobeiras': [],
#  'Divinópolis': ['divinopolis.csv'],
#  'Lagoa da Prata,Santo Antônio do Monte': [],
#  'Oliveira,Santo Antônio do Amparo': ['oliveira.csv'],
#  'Campo Belo': [],
#  'Lima Duarte': [],
#  'Cássia': [],
#  'Passos': ['passos.csv'],
#  'Piumhi': [],
#  'Almenara,Jacinto': ['almenara.csv'],
#  'Serro': [],
#  'Itambacuri': [],
#  'Juiz de Fora': ['juiz_de_fora.csv'],
#  'Salinas': ['salinas.csv'],
#  'Teófilo Otoni,Malacacheta': ['teofilo_otoni.csv'],
#  'São Francisco': [],
#  'Brasília de Minas': [],
#  'Peçanha,São João Evangelista,Santa Maria do Suaçuí': []}

# %%
def treat(name):
    ok = False
    for k, v in mapping.items():
        if name in v:
            mun = k
            ok = True
    if not ok:
        return 'not found', False
    
    df = pd.read_csv(name, sep=';', encoding='latin-1').fillna(',0')
    df = df.loc[:,['Data', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)']]
    df['Data'] = pd.to_datetime(df['Data'])
    df['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = \
        df['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)']\
        .str.replace(',', '.')\
        .astype(float)
    new_df = df.groupby(df['Data'])\
        .sum()\
        .rename(
            columns={
                'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)': 'Precipitação'
            }
        )
    new_df.reset_index(inplace=True)
    start_date = pd.Timestamp('2023-12-31')
    new_df['Semana'] = ((new_df['Data']-start_date).dt.days//7)+1
    new_df['Semana'] = new_df['Semana'].apply(lambda x: f'Semana {x}')
    new_df.pop('Data')
    new_df = new_df.groupby('Semana').sum()
    new_df = new_df.T
    new_df.rename(columns={'index': 'Município'})
    new_df['Município'] = mun
    new_df.set_index('Município', inplace=True)
    return new_df, True

# %%
treat('diamantina.csv')
# Out:
# (Semana                   Semana 1  Semana 10  Semana 11  Semana 12  Semana 13  \
#  Município
#  Diamantina,Itamarandiba     138.0        6.4       47.6       56.0       10.8
#
#  Semana                   Semana 14  Semana 15  Semana 16  Semana 17  \
#  Município
#  Diamantina,Itamarandiba       20.6        3.0        3.0        4.4
#
#  Semana                   Semana 18  ...  Semana 49  Semana 5  Semana 50  \
#  Município                           ...
#  Diamantina,Itamarandiba        0.2  ...       17.0      21.4       51.0
#
#  Semana                   Semana 51  Semana 52  Semana 53  Semana 6  Semana 7  \
#  Município
#  Diamantina,Itamarandiba       85.6      143.6       47.4      92.0      39.8
#
#  Semana                   Semana 8  Semana 9
#  Município
#  Diamantina,Itamarandiba     163.0      20.2
#
#  [1 rows x 53 columns],
#  True)

# %%
import os
dfs = []
for filename in os.listdir():
    if 'csv' not in filename:
        continue
    print(filename)
    df, ok = treat(filename)
    if ok:
        dfs.append(df)
        #df.to_csv(f'../week-data/{filename}-weeks.csv', encoding='latin-1')
        
total = pd.concat(dfs)
total.to_csv('../pluvio.csv', encoding='latin-1')
# Out:
# aimores.csv
# januaria.csv
# montalvania.csv
# guanhaes.csv
# dores_do_indaia.csv
# aracuai.csv
# sacramento.csv
# rio_pardo_de_minas.csv
# uberaba.csv
# teofilo_otoni.csv
# ouro_branco.csv
# almenara.csv
# patos_de_minas.csv
# capelinha.csv
# montes_claros.csv
# passos.csv
# barbacena.csv
# curvelo.csv
# salinas.csv
# paracatu.csv
# caratinga.csv
# nova_porteirinha_(janauba).csv
# coronel_pacheco.csv
# tres_marias.csv
# aguas_vermelhas.csv
# buritis.csv
# governador_valadares.csv
# uberlandia.csv
# varginha.csv
# espinosa.csv
# formiga.csv
# sao_sebastiao_do_paraiso.csv
# conceicao_das_alagoas.csv
# sao_romao.csv
# guarda-mor.csv
# mocambinho.csv
# muriae.csv
# caldas.csv
# patrocinio.csv
# machado.csv
# monte_verde.csv
# joao_pinheiro.csv
# oliveira.csv
# sete_lagoas.csv
# maria_da_fe.csv
# chapada_gaucha.csv
# mantena.csv
# araxa.csv
# belo_horizonte_(pampulha).csv
# belo_horizonte_-_cercadinho.csv
# manhuacu.csv
# florestal.csv
# itaobim.csv
# pompeu.csv
# campina_verde.csv
# pirapora.csv
# diamantina.csv
# serra_dos_aimores.csv
# passa_quatro.csv
# sao_joao_del_rei.csv
# vicosa.csv
# divinopolis.csv
# ituiutaba.csv
# bambui.csv
# ibirite_(rola_moca).csv
# timoteo.csv
# unai.csv
# juiz_de_fora.csv
